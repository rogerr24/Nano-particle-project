# %%
# --- Initial Exploratory Data Analysis (EDA) ---

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns # Ensure this line is present if you want to use seaborn

# Load the dataset (now the path should work, assuming VS Code starts in Nano-particle-project)
df = pd.read_csv('data/nanotox_dataset.csv.csv')
pd.set_option('display.max_columns', None)  # Show all columns in the output
pd.set_option('display.max_rows', None)     # Show all rows in the output

display(df)# Use display() for nicer table output in Jupyter

print("\n--- Dataset Info ---")
df.info()

print("\n--- Descriptive Statistics for Numerical Columns ---")
display(df.describe())

print("\n--- Value Counts for Categorical Columns ---")
if 'class' in df.columns:
    print("\nValue counts for 'class' column:")
    print(df['class'].value_counts())
else:
    print("\nNo 'class' column found or other categorical columns to show value counts for.")
# Out:
#        NPs  coresize  hydrosize  surfcharge  surfarea    Ec  Expotime  \
# 0    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 1    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 2    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 3    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 4    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 5    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 6    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 7    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 8    Al2O3      39.7      267.0       36.30     64.70 -1.51        24
# 9    Al2O3      39.7      267.0       36.30     64.70 -1.51        12
# 10   Al2O3      39.7      267.0       36.30     64.70 -1.51        12
# 11   Al2O3      39.7      267.0       36.30     64.70 -1.51        12
# ...
